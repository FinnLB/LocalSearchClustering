# %%
from matplotlib import pyplot as plt

# %%
from sklearn import cluster, datasets, mixture
import numpy as np

n_samples = 120
seed = 30
noisy_circles, _ = datasets.make_circles(
    n_samples=n_samples, factor=0.5, noise=0.05, random_state=seed
)
noisy_moons, _ = datasets.make_moons(n_samples=n_samples, noise=0.05, random_state=seed)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=seed)
rng = np.random.RandomState(seed)
no_structure = rng.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# %%
from main import ls_clustering_beam, ls_clustering_dla

def cluster_and_plot(X,):
    plt.scatter(X[:, 0], X[:, 1], c=ls_clustering_beam(X))

# %%
cluster_and_plot(noisy_circles)

# %%
cluster_and_plot(noisy_moons)

# %%
from main import ls_clustering_genetic

def cluster_and_plot_genetic(X,):
    plt.scatter(X[:, 0], X[:, 1], c=ls_clustering_genetic(X))

# %%
from hdbscan import hdbscan

plt.scatter(noisy_moons[:, 0], noisy_moons[:, 1], c=hdbscan(noisy_moons)[0])

# %%
from hdbscan import hdbscan

plt.scatter(noisy_circles[:, 0], noisy_circles[:, 1], c=hdbscan(noisy_circles)[0])
